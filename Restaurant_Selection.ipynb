# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt


from keys import Trip_advisor_key
from keys import geoapify_key

# %%
# Defining the District dataframe

Districts_df = pd.DataFrame({
    'Location': ['Toronto Distillery District', 'Toronto GTA Area', 'Toronto Downtown', 'Toronto King West', 'Toronto Queen West' , 'Toronto College West', 'Toronto Yorkville','Toronto Old Town', 'Toronto Airport', 'Ottawa City Centre', 'Ottawa Rideau Canal' , 'Niagara Falls' , 'Niagara Park'],
    'Lat': [43.6503, 43.6426 , 43.655064 , 43.642567, 43.647044, 43.6552,  43.6707 , 43.3906, 43.6817, 45.4236, 45.3961 , 43.087586 , 43.0914], 
    'Lng': [-79.3596, -79.3871, -79.386563 , -79.387054, -79.403698, -79.4139,  -79.3930 , -79.2253 ,  -79.6145, -75.7009, -75.6883 , -79.081206 , -79.0756]  
})

Districts_df.to_csv("output/Districts.csv", index_label="Restaurant ID")

# Defining the Restaurant DataFrame

Restaurants_df = pd.DataFrame(columns=['Location', 'Restaurant Name', 'Postal Code', 'Restaurant Address', 'Lat', 'Lng'])

# Loop for districts
err = 0

radius = 1000

params = {
    'categories': 'catering.restaurant',
    'apiKey': geoapify_key,
    'limit':50
}

base_url = 'https://api.geoapify.com/v2/places'

for index, row in Districts_df.iterrows():
    latitude = row['Lat']
    longitude = row['Lng']

    params['filter'] = f'circle:{longitude},{latitude},{radius}'
    params['bias'] = f'proximity:{longitude},{latitude}'

    response = requests.get(base_url, params=params).json()
    for restaurant in response.get('features', []):
        try:
            
            new_row = {
                            'Location': row['Location'],
                            'Restaurant Name': restaurant["properties"]["address_line1"],
                            'Postal Code' : restaurant["properties"]["postcode"],
                            'Restaurant Address': restaurant["properties"]["address_line2"],
                            'Lat': restaurant["geometry"]["coordinates"][1],
                            'Lng': restaurant["geometry"]["coordinates"][0]
                        }
            
            Restaurants_df.loc[len(Restaurants_df)] = new_row
        except(KeyError, IndexError):
            err = err + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 22
#      16 err = 0
#      18 radius = 1000
#      20 params = {
#      21     'categories': 'catering.restaurant',
# ---> 22     'apiKey': geoapify_key,
#      23     'limit':50
#      24 }
#      26 base_url = 'https://api.geoapify.com/v2/places'
#      28 for index, row in Districts_df.iterrows():
#
# NameError: name 'geoapify_key' is not defined

# %%
Restaurants_df.head()
# Out:
#                       Location        Restaurant Name Postal Code  \
# 0  Toronto Distillery District       Archeo Trattoria     M5A 3C4
# 1  Toronto Distillery District              El Catrin     M5A 3C4
# 2  Toronto Distillery District   Oyster House & grill     M5A 3C4
# 3  Toronto Distillery District           Pure Spirits     M5A 3C4
# 4  Toronto Distillery District  The Fermenting Cellar     M5A 3C4
#
#                                   Restaurant Address        Lat        Lng
# 0  31 Trinity Street, Old Toronto, ON M5A 3C4, Ca...  43.650682 -79.359630
# 1       Mill Street, Old Toronto, ON M5A 3C4, Canada  43.650693 -79.359245
# 2   Tank House Lane, Old Toronto, ON M5A 3C4, Canada  43.650350 -79.358811
# 3  17 Tank House Lane, Old Toronto, ON M5A 3C4, C...  43.650395 -79.358754
# 4  28 Distillery Lane, Old Toronto, ON M5A 3C4, C...  43.649806 -79.360538

# %%
#Drill for location_id

Restaurants_df['Location ID'] = ''

err_count = 0


for index, restaurant in Restaurants_df.iterrows():
    
    url = f"https://api.content.tripadvisor.com/api/v1/location/search?key={Trip_advisor_key}&searchQuery={restaurant['Restaurant Name']}&language=en"

    headers = {"accept": "application/json"}

    response = requests.get(url, headers=headers).json()
    
    try:
        
        for res in response['data']:
    
            if res['address_obj']['postalcode'] == restaurant['Postal Code']:
            
                Restaurants_df.at[index, 'Location ID'] = res['location_id']
                
                break
    
    except Exception as e:
        
        err_count = err_count +1
        
        


Restaurants_df.head()
# Out:
# 214
#                       Location        Restaurant Name Postal Code  \
# 0  Toronto Distillery District       Archeo Trattoria     M5A 3C4
# 1  Toronto Distillery District              El Catrin     M5A 3C4
# 2  Toronto Distillery District   Oyster House & grill     M5A 3C4
# 3  Toronto Distillery District           Pure Spirits     M5A 3C4
# 4  Toronto Distillery District  The Fermenting Cellar     M5A 3C4
#
#                                   Restaurant Address        Lat        Lng  \
# 0  31 Trinity Street, Old Toronto, ON M5A 3C4, Ca...  43.650682 -79.359630
# 1       Mill Street, Old Toronto, ON M5A 3C4, Canada  43.650693 -79.359245
# 2   Tank House Lane, Old Toronto, ON M5A 3C4, Canada  43.650350 -79.358811
# 3  17 Tank House Lane, Old Toronto, ON M5A 3C4, C...  43.650395 -79.358754
# 4  28 Distillery Lane, Old Toronto, ON M5A 3C4, C...  43.649806 -79.360538
#
#   Location ID
# 0     5078107
# 1     4556927
# 2
# 3      708144
# 4

# %%
#Drop row with empty records
Restaurants_df = Restaurants_df[Restaurants_df['Location ID'] != '']

# %%
# Export the City_Data into a csv
Restaurants_df.to_csv("output/restaurants.csv", index_label="Restaurant ID")

# %%
Restaurants_df.head()
# Out:
#                         Location        Restaurant Name Postal Code  \
# 0    Toronto Distillery District       Archeo Trattoria     M5A 3C4
# 1    Toronto Distillery District              El Catrin     M5A 3C4
# 3    Toronto Distillery District           Pure Spirits     M5A 3C4
# 5    Toronto Distillery District                  Cluny     M5A 3C4
# 20   Toronto Distillery District     Fusilli Ristorante     M5A 1V1
# ..                           ...                    ...         ...
# 481                 Niagara Park  Remingtons of Niagara     L2G 3L5
# 486                 Niagara Park        Rainforest Cafe     L2G 3N5
# 488                 Niagara Park             Weinkeller     L2G 3L5
# 504                 Niagara Park      Italian ice cream     L2G 3L2
# 510                 Niagara Park         AlMac's Buffet     L2G 1S2
#
#                                     Restaurant Address        Lat        Lng  \
# 0    31 Trinity Street, Old Toronto, ON M5A 3C4, Ca...  43.650682 -79.359630
# 1         Mill Street, Old Toronto, ON M5A 3C4, Canada  43.650693 -79.359245
# 3    17 Tank House Lane, Old Toronto, ON M5A 3C4, C...  43.650395 -79.358754
# 5     Tank House Lane, Old Toronto, ON M5A 3C4, Canada  43.650604 -79.357865
# 20   531 Queen Street East, Old Toronto, ON M5A 1V1...  43.657075 -79.357150
# ..                                                 ...        ...        ...
# 481  Victoria Avenue, Niagara Falls, ON L2G 3L5, Ca...  43.092884 -79.075022
# 486  4915 Clifton Hill, Niagara Falls, ON L2G 3N5, ...  43.091131 -79.073119
# 488  5633 Victoria Avenue, Niagara Falls, ON L2G 3L...  43.093301 -79.074329
# 504  5458 Victoria Avenue, Niagara Falls, ON L2G 3L...  43.095683 -79.072737
# 510  5435 Ferry Street, Niagara Falls, ON L2G 1S2, ...  43.089775 -79.084329
#
#     Location ID
# 0       5078107
# 1       4556927
# 3        708144
# 5       6762792
# 20       704440
# ..          ...
# 481     1479180
# 486      708192
# 488     4752346
# 504     1917372
# 510     1110107
#
# [98 rows x 7 columns]
