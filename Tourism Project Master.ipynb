# %%
# %run CATSA Flight Data.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\IPython\core\magics\execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File D:\Anaconda\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'CATSA'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'CATSA Flight Data.ipynb')
#
# ...

# %%
# %run Hotel_data_12112023.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20336\1645416700.py:5
#       3 import requests
#       4 import json
# ----> 5 from config import api_key
#       6 from pprint import pprint
#       7 from pathlib import Path
#
# ModuleNotFoundError: No module named 'config'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Hotel_data_12112023.ipynb')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
# ...

# %%
# %run Demographics-Tourism.ipynb

# %%
# %run Restaurant_Selection.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20336\41625632.py:5
#       2 import requests
#       3 import matplotlib.pyplot as plt
# ----> 5 from keys import Trip_advisor_key
#       6 from keys import geoapify_key
#
# ModuleNotFoundError: No module named 'keys'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Restaurant_Selection.ipynb')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
# ...

# %%
# %run Restaurant_Reviews_Drill.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20336\3074105190.py:4
#       1 import pandas as pd
#       2 import requests
# ----> 4 from keys import Trip_advisor_key
#
# ModuleNotFoundError: No module named 'keys'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Restaurant_Reviews_Drill.ipynb')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
# ...

# %%
# %run Plotting_Restaurants.ipynb
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1030', ...)

# %%
# %run Drink Place Plot.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\IPython\core\magics\execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File D:\Anaconda\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'Drink'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Drink Place Plot.ipynb')
#
# ...

# %%
# %run Google_Place_Code.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20336\3106508657.py:1
# ----> 1 import googlemaps
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'googlemaps'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Google_Place_Code.ipynb')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
# ...

# %% [raw]
# %run Relevant Review Plot Code.ipynb

# %%
# %run Travel_Advisor_Code.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_20336\3017339200.py:7
#       5 from pathlib import Path
#       6 from pprint import pprint
# ----> 7 from res_config import api_key
#       8 import requests
#
# ModuleNotFoundError: No module named 'res_config'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_line_magic('run', 'Travel_Advisor_Code.ipynb')
#
# File D:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
# ...

# %%
# %run Trip_Advisor_Code.ipynb
